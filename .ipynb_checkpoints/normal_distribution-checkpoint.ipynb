# %% [markdown]
# ## Import Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Defining a Random Normal Distribution

# %% [markdown]
# Let's define our example data. We want to generate random samples with NumPy.
#
# Let's have a look at several examples. We define several example values for the mean and the standard deviation

# %% [markdown]
# ### Example 1 (Standard Normal Distribution): Mean = 0, Standard Deviation = 1

# %%
mean = 0
standard_deviation = 1

data_example1 = np.random.normal(mean, standard_deviation, size=20000)

print(sample_data_example1)
# Out:
# [ 0.64432568  0.08148269  2.42078934 ... -2.91695444 -0.85257223
#  -0.11957461]

# %% [markdown]
# Let's visualize our data with Matplotlib

# %%
plt.hist(data_example1, bins=100, color='b')
plt.xlim(-7, 7)
plt.ylim(0, 800)
plt.show()

# %% [markdown]
# ### Example 2: Mean = 0, Standard Deviation = 0,5

# %%
mean = 0
standard_deviation = 0.5

data_example2 = np.random.normal(mean, standard_deviation, size=20000)

print(data_example2)
# Out:
# [-0.26691194  0.47892278  0.19972155 ...  0.24330451  0.98508512
#  -0.15636882]

# %% [markdown]
# Let's visualize our data with Matplotlib

# %%
plt.hist(data_example2, bins=100, color='r')
plt.xlim(-7, 7)
plt.ylim(-0, 800)
plt.show()

# %% [markdown]
# ### Example 3: Mean = 1, Standard Deviation = 2

# %%
mean = 1
standard_deviation = 2

data_example3 = np.random.normal(mean, standard_deviation, size=20000)

print(data_example3)
# Out:
# [ 2.72886362  2.62843006 -0.10473585 ...  1.4734961   0.3347582
#  -0.56342267]

# %% [markdown]
# Let's visualize our data with Matplotlib

# %%
plt.hist(data_example3, bins=100, color='g')
plt.xlim(-7, 7)
plt.ylim(0, 800)
plt.show()

# %% [markdown]
# ### Comparison

# %%
#Set figure size
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(7)

#plot 1
plt.subplot(3, 1, 1)
plt.hist(data_example1, bins=100, color='b')
plt.xlim(-7, 7)
plt.ylim(0, 800)
plt.title('Example 1: Mean = 0, Standard Deviation = 1')

#plot 2
plt.subplot(3, 1, 2)
plt.hist(data_example2, bins=100, color='r')
plt.xlim(-7, 7)
plt.ylim(0, 800)
plt.title('Example 2: Mean = 0, Standard Deviation = 0.5')

#plot 3
plt.subplot(3, 1, 3)
plt.hist(data_example3, bins=100, color='g')
plt.xlim(-7, 7)
plt.ylim(0, 800)
plt.title('Example 3: Mean = 1, Standard Deviation = 2')

plt.tight_layout()
plt.show()
